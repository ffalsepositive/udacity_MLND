# %% [markdown]
# # Model Deployment

# %%
import sys
sys.path.append("../")

import pandas as pd

index_cols = [
    "dataset", "customer_id", "offer_id", "order"
]

feat_cols = [
    'recurrence', 'time', 'amount', 'total_trans_amount', 'total_trans_count', 
    'avg_trans_amount', 'time_after_last_trans', 'web', 'mobile', 'social', 
    'was_null_profile', 'oft_bogo', 'oft_discount', 'dfc_5', 'dfc_10', 'delta_3', 
    'delta_4', 'delta_5', 'delta_7', 'delta_10', 'rw_0', 'rw_2', 'rw_3', 'rw_5', 'rw_10', 
    'member_new', 'member_old', 'gen_F', 'gen_O', 'age_18_23', 'age_24_29', 'age_30_35', 
    'age_36_41', 'age_42_47', 'age_48_53', 'age_53_59', 'age_60_65', 'age_66_71', 'age_72_77', 
    'age_78_83', 'age_84_101', 'income_30k_40k', 'income_40k_50k', 'income_50k_60k', 
    'income_60k_75k', 'income_75k_100k', 'income_100k_120k'
]

target_cols = ["target"]

def load_customer_data(customer_id, dataset="train"):
    data = pd.read_csv("../data/processed/{}.csv".format(dataset), index_col=0)
    data.index.name = "index"
    data = data.reset_index()
    
    cols = {0:"customer_id", 1:"offer_id", 2:"order"}
    df = data["index"].str.split("-",expand=True).rename(columns=cols)
    
    data = data.join(df).drop(columns=["index"])
    data["dataset"] = dataset
    
    return  data[data["customer_id"] == customer_id].reset_index(drop=True)

def run_model(model, customer_id):
    train = load_customer_data(customer_id, "train")
    test = load_customer_data(customer_id, "test")

    df = pd.concat([train, test], axis=0)
    
    if len(df) == 0:
        return True, None
    else:
        pred_data = df[feat_cols].values
        df["prob_c0"] = model.predict_proba(pred_data)[:, 0]
        df["prob_c1"] = model.predict_proba(pred_data)[:, 1]
        df["prob_c2"] = model.predict_proba(pred_data)[:, 2]

        prob_cols = ["prob_c" + str(i) for i in range(3)]

        df = df[index_cols + feat_cols + prob_cols + target_cols].reset_index()
        df.index = df["dataset"] + "_sample_no: " + df["index"].astype(str)
        df = df.drop(columns=["index", "dataset"], axis=1)
    
    return False, df.T

# %%
import pickle
model = pickle.load(open("../deployment/models/rforest_hyp.pkl", "rb"))

# %%
_, df = run_model(model, "00d7c95f793a4212af44e632fdc1e431")

# %%
df
# Out:
#                                      train_sample_no: 0  \
# customer_id            00d7c95f793a4212af44e632fdc1e431
# offer_id               2906b810c7d4411798c6938adc9daaa5
# order                                                 1
# recurrence                                         0.25
# time                                                0.4
# amount                                         0.020603
# total_trans_amount                             0.037739
# total_trans_count                              0.035714
# avg_trans_amount                               0.025976
# time_after_last_trans                          0.473684
# web                                                   1
# mobile                                                1
# social                                                0
# was_null_profile                                      0
# oft_bogo                                              0
# oft_discount                                          1
# dfc_5                                                 0
# dfc_10                                                1
# delta_3                                               0
# delta_4                                               0
# delta_5                                               0
# delta_7                                               1
# delta_10                                              0
# rw_0                                                  0
# rw_2                                                  1
# rw_3                                                  0
# rw_5                                                  0
# rw_10                                                 0
# member_new                                            0
# member_old                                            0
# gen_F                                                 0
# gen_O                                                 0
# age_18_23                                             0
# age_24_29                                             0
# age_30_35                                             0
# age_36_41                                             0
# age_42_47                                             0
# age_48_53                                             0
# age_53_59                                             0
# age_60_65                                             0
# age_66_71                                             1
# age_72_77                                             0
# age_78_83                                             0
# age_84_101                                            0
# income_30k_40k                                        0
# income_40k_50k                                        0
# income_50k_60k                                        0
# income_60k_75k                                        0
# income_75k_100k                                       1
# income_100k_120k                                      0
# prob_c0                                        0.777737
# prob_c1                                        0.039649
# prob_c2                                        0.182613
# target                                                0
#
#                                      train_sample_no: 1  \
# customer_id            00d7c95f793a4212af44e632fdc1e431
# offer_id               9b98b8c7a33c4b65b9aebfe6a799e6d9
# order                                                 0
# recurrence                                          0.0
# time                                                0.4
# amount                                         0.020603
# total_trans_amount                             0.037739
# total_trans_count                              0.035714
# avg_trans_amount                               0.025976
# time_after_last_trans                          0.305263
# web                                                   1
# mobile                                                1
# social                                                0
# was_null_profile                                      0
# oft_bogo                                              1
# oft_discount                                          0
# dfc_5                                                 1
# dfc_10                                                0
# delta_3                                               0
# delta_4                                               0
# delta_5                                               0
# delta_7                                               1
# delta_10                                              0
# rw_0                                                  0
# rw_2                                                  0
# rw_3                                                  0
# rw_5                                                  1
# rw_10                                                 0
# member_new                                            0
# member_old                                            0
# gen_F                                                 0
# gen_O                                                 0
# age_18_23                                             0
# age_24_29                                             0
# age_30_35                                             0
# age_36_41                                             0
# age_42_47                                             0
# age_48_53                                             0
# age_53_59                                             0
# age_60_65                                             0
# age_66_71                                             1
# age_72_77                                             0
# age_78_83                                             0
# age_84_101                                            0
# income_30k_40k                                        0
# income_40k_50k                                        0
# income_50k_60k                                        0
# income_60k_75k                                        0
# income_75k_100k                                       1
# income_100k_120k                                      0
# prob_c0                                        0.902849
# prob_c1                                        0.019905
# prob_c2                                        0.077246
# target                                                0
#
#                                      train_sample_no: 2  \
# customer_id            00d7c95f793a4212af44e632fdc1e431
# offer_id               2906b810c7d4411798c6938adc9daaa5
# order                                                 0
# recurrence                                          0.0
# time                                                0.4
# amount                                         0.020603
# total_trans_amount                             0.037739
# total_trans_count                              0.035714
# avg_trans_amount                               0.025976
# time_after_last_trans                          0.178947
# web                                                   1
# mobile                                                1
# social                                                0
# was_null_profile                                      0
# oft_bogo                                              0
# oft_discount                                          1
# dfc_5                                                 0
# dfc_10                                                1
# delta_3                                               0
# delta_4                                               0
# delta_5                                               0
# delta_7                                               1
# delta_10                                              0
# rw_0                                                  0
# rw_2                                                  1
# rw_3                                                  0
# rw_5                                                  0
# rw_10                                                 0
# member_new                                            0
# member_old                                            0
# gen_F                                                 0
# gen_O                                                 0
# age_18_23                                             0
# age_24_29                                             0
# age_30_35                                             0
# age_36_41                                             0
# age_42_47                                             0
# age_48_53                                             0
# age_53_59                                             0
# age_60_65                                             0
# age_66_71                                             1
# age_72_77                                             0
# age_78_83                                             0
# age_84_101                                            0
# income_30k_40k                                        0
# income_40k_50k                                        0
# income_50k_60k                                        0
# income_60k_75k                                        0
# income_75k_100k                                       1
# income_100k_120k                                      0
# prob_c0                                        0.716146
# prob_c1                                        0.030637
# prob_c2                                        0.253218
# target                                                2
#
#                                       test_sample_no: 0
# customer_id            00d7c95f793a4212af44e632fdc1e431
# offer_id               fafdcd668e3743c1bb461111dcafc2a4
# order                                                 0
# recurrence                                          0.0
# time                                           0.978947
# amount                                         0.028998
# total_trans_amount                             0.103668
# total_trans_count                              0.178571
# avg_trans_amount                               0.023765
# time_after_last_trans                          0.021053
# web                                                   1
# mobile                                                1
# social                                                1
# was_null_profile                                      0
# oft_bogo                                              0
# oft_discount                                          1
# dfc_5                                                 0
# dfc_10                                                1
# delta_3                                               0
# delta_4                                               0
# delta_5                                               0
# delta_7                                               0
# delta_10                                              1
# rw_0                                                  0
# rw_2                                                  1
# rw_3                                                  0
# rw_5                                                  0
# rw_10                                                 0
# member_new                                            0
# member_old                                            0
# gen_F                                                 0
# gen_O                                                 0
# age_18_23                                             0
# age_24_29                                             0
# age_30_35                                             0
# age_36_41                                             0
# age_42_47                                             0
# age_48_53                                             0
# age_53_59                                             0
# age_60_65                                             0
# age_66_71                                             1
# age_72_77                                             0
# age_78_83                                             0
# age_84_101                                            0
# income_30k_40k                                        0
# income_40k_50k                                        0
# income_50k_60k                                        0
# income_60k_75k                                        0
# income_75k_100k                                       1
# income_100k_120k                                      0
# prob_c0                                        0.959148
# prob_c1                                        0.040852
# prob_c2                                             0.0
# target                                                0
